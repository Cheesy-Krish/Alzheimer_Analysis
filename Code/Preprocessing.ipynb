# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img =cv2.imread("Alzheimer_s Dataset/train/NonDemented/nonDem0.jpg",cv2.IMREAD_COLOR)
plt.imshow(img)

# %%
image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
imgResize = cv2.resize(image, (200, 200))
blur = cv2.GaussianBlur(imgResize,(5,5),0)
imgSegmented = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)[1]
imgCanny=cv2.Canny(imgSegmented,50,50)

# %%
plt.imshow(image,cmap='gray')

# %%
plt.imshow(imgResize,cmap='gray')

# %%
plt.imshow(blur,cmap='gray')

# %%
plt.imshow(imgSegmented,cmap='gray')

# %%
plt.imshow(imgCanny,cmap='gray')
